# %%
# @title Cristal armonico
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(12,6))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 0.1, 20000)  # Create a time array from 0 to 10 with 20000 points
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  T=1
  def Emn(N, m, n):

      M = (1.99*(10**-23))*k
      mu = 0.02

      E = n**2 / (2 * M * (N + m)) + mu * m

      return E

  def f(N, t):
      kb = 1.380649*(10**-24)
      Z = 0
      T=1
      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kb*T)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 6.62607015*(10**-34)
          exp_term1 = np.exp(-Emn(N, 0, i) / kb*T)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza de un cristal armónico ; N={N} ; T={T}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Cristal armonico
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))


def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 100000, 20000)  # Create a time array from 0 to 10 with 20000 points
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  def Emn(N, m, n):
      M = 0.1*k
      mu = 0.2
      E = n**2 / (2 * M * (N + m)) + mu * m
      return E

  def f(N, t):
      kbt = 0.1
      Z = 0

      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza de un cristal armónico ; N={N}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Cristal armonico
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 1000000, 20000)
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  def Emn(N, m, n):
      M = 0.1*k
      mu = 0.2
      E = n**2 / (2 * M * (N + m)) + mu * m
      return E

  def f(N, t):
      kbt = 0.1
      Z = 0

      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza de un cristal armónico; N={N}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Cristal armonico
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 5000000, 200000)
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  def Emn(N, m, n):
      M = 0.1*k
      mu = 0.2
      E = n**2 / (2 * M * (N + m)) + mu * m
      return E

  def f(N, t):
      kbt = 0.1
      Z = 0

      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza de un cristal armónico; N={N}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Modelo de Cristal armónico modulado
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(12,6))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 500000, 20000)
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  def Emn(N, m, n):
      M = 0.1*k
      mu = 0.2
      B=1
      E = n*np.sqrt(B/(2 * M * (N + m))) + mu * m
      return E

  def f(N, t):
      kbt = 0.1
      Z = 0

      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza ", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Modelo de Cristal armónico modulado
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(12,6))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 500000, 20000)
N = 1000

for k in [1,2,3,4,12]:
  M = truncate(0.1*k,2)
  def Emn(N, m, n):
      M = 0.1*k
      mu = 0.2
      B=1
      E = n*np.sqrt(B/(2 * M * (N + m))) + mu * m
      return E

  def f(N, t):
      kbt = 0.1
      Z = 0

      # Compute partition function Z
      for j in range(N):
          Z += np.exp(-Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2 / Z

      return (result * np.conj(result)).real / 2 + 1/2

  # Create the dependent array using the function
  y = f(N, t)
  ax.plot(t, y,label=f"M={M}")

ax.set_title(f"Pureza ", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo',fontsize=14)
ax.set_ylabel('Pureza',fontsize=14)
ax.legend(fontsize=14)

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 50000, 20000)
N = 1000
delta = 0.1

for k in [1,3,12]:
    J = truncate(0.1 * k, 2)

    def Emn(N, m, n):
        J = 0.1 * k
        delta = 0.1
        B = 1

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 0.1
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"J={J}")

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math


fig, [ax,ax2] = plt.subplots(ncols=2, nrows=1,figsize=(26,12))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor
tlim=70000
# Define the time array
t = np.linspace(0, tlim, 30000)
N = 1000

for k in [1,0.1,0.01]:

    B = truncate(1 * k, 2)
    def Emn(N, m, n):
        J = 0.1
        delta = 0.1
        B = 1 * k

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 0.1
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"B={B}")

for p in [1,2]:
  N_=int(p*N)
  def Emn(N, m, n):
      J = 0.1
      delta = 0.1
      B_ = B

      S_a = N * delta / 2 - m / 2
      Eth = np.sqrt(2 * delta * J * B_)
      Esim = J * (-2 * S_a * (S_a + 1)) / N
      E = Esim - B_ * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B_) - m * (n + 1/2) * Eth / (2 * N * delta)
      return E

  def f(N, t):
      kbt = 0.1
      log_Z = -np.inf  # Initialize to log(0)

      # Compute log partition function log(Z)
      for j in range(N):
          log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2

      return (result * np.conj(result)).real / 2 + 1/2

  t = np.linspace(0, tlim, 10000)
  y = f(N_, t)
  ax2.plot(t, y, label=f"N={N_}")

ax2.set_title(f"Pureza - Modelo Lieb Matis - J={J} - Δ={delta} - B={B}", fontsize=14)
ax2.grid()
ax2.set_xlabel('Tiempo', fontsize=14)
ax2.set_ylabel('Pureza', fontsize=14)
ax2.legend(fontsize=14)

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math


fig, [ax,ax2] = plt.subplots(ncols=2, nrows=1,figsize=(26,12))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 30000, 30000)
N = 1000

for p in [0.1,1,2]:
  N_=int(p*N)
  def Emn(N, m, n):
      J = 0.1
      delta = 0.1
      B_ = B

      S_a = N * delta / 2 - m / 2
      Eth = np.sqrt(2 * delta * J * B_)
      Esim = J * (-2 * S_a * (S_a + 1)) / N
      E = Esim - B_ * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B_) - m * (n + 1/2) * Eth / (2 * N * delta)
      return E

  def f(N, t):
      kbt = 2
      log_Z = -np.inf  # Initialize to log(0)

      # Compute log partition function log(Z)
      for j in range(N):
          log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

      # Initialize result
      result = np.zeros_like(t, dtype=np.complex128)

      for i in range(N):
          h = 1
          exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
          exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
          result += exp_term1 * exp_term2

      return (result * np.conj(result)).real / 2 + 1/2

  t = np.linspace(0, 30000, 10000)
  y = f(N_, t)
  ax2.plot(t, y, label=f"N={N_}")


for k in [12,5,0.1,0.01]:

    B = truncate(1 * k, 2)
    def Emn(N, m, n):
        J = 0.1
        delta = 0.1
        B = 1 * k

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 0.1
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"B={B}")


ax2.set_title(f"Pureza - Modelo Lieb Matis - J={J} - Δ={delta} - B={B}", fontsize=14)
ax2.grid()
ax2.set_xlabel('Tiempo', fontsize=14)
ax2.set_ylabel('Pureza', fontsize=14)
ax2.legend(fontsize=14)

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(26,12))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 10, 30000)

J = 0.1
delta = 0.1

def f(N, t):
      kbt = 1
      log_Z = -np.inf  # Initialize to log(0)
      J = 0.3
      delta = 1
      B_ = 1/N
      Eth = np.sqrt( J * B_)

      x=Eth/kbt
      tau=2*Eth*t/N

      result = np.zeros_like(t, dtype=np.complex128)

      result= ((1-np.exp(-x))/(1-np.exp(-N*x)))*((1-np.exp(-N*(x+ 1j*t)))/(1-np.exp(-(x+ 1j*t))))

      return (result * np.conj(result)).real / 2 + 1/2

for p in [0.1,1]:
  N = 100*p

  t = np.linspace(0, 30000, 10000)
  y = f(N, t)
  ax.plot(t, y, label=f"N={N}")

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 20000, 20000)
N = 1000

for k in [0.1,1,12]:
    J = truncate(0.1 * k, 2)
    delta = truncate(0.1 * k, 2)
    B=1
    def Emn(N, m, n):
        J = 0.01
        delta = 0.01* k
        B = 1

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 1
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"Δ={delta}")

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - B={B}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(12,6))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 20000, 20000)
N = 1000

for k in [1,12]:
    J = truncate(0.1 * k, 2)
    delta = 0.1
    B = 1
    def Emn(N, m, n):
        J = 0.01 * k
        delta = 0.1
        B = 1

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 1
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"J={J}")

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()

# %%
# @title Modelo de Lieb Matis
import numpy as np
import matplotlib.pyplot as plt
import math

fig, ax = plt.subplots(figsize=(20,9))

def truncate(number, decimals=0):
    factor = 10.0 ** decimals
    return int(number * factor) / factor

# Define the time array
t = np.linspace(0, 20000, 20000)
N = 1000

for k in [1,2,6,12]:
    J = truncate(0.1 * k, 2)
    delta = 0.01
    def Emn(N, m, n):
        J = 0.01
        delta = 0.01
        B = 1

        S_a = N * delta / 2 - m / 2
        Eth = np.sqrt(2 * delta * J * B)
        Esim = J * (-2 * S_a * (S_a + 1)) / N
        E = Esim - B * N * delta + (n + 1/2) * Eth + m * (2 * delta * J + B) - m * (n + 1/2) * Eth / (2 * N * delta)
        return E

    def f(N, t):
        kbt = 0.01*k
        log_Z = -np.inf  # Initialize to log(0)

        # Compute log partition function log(Z)
        for j in range(N):
            log_Z = np.logaddexp(log_Z, -Emn(N, 0, j) / kbt)

        # Initialize result
        result = np.zeros_like(t, dtype=np.complex128)

        for i in range(N):
            h = 1
            exp_term1 = np.exp(-Emn(N, 0, i) / kbt - log_Z)
            exp_term2 = np.exp(-1j * t * (Emn(N, 2, i) - Emn(N, 0, i)) / h)
            result += exp_term1 * exp_term2

        return (result * np.conj(result)).real / 2 + 1/2

    kbt = truncate(0.01 * k, 2)

    # Create the dependent array using the function
    y = f(N, t)
    ax.plot(t, y, label=f"Kb T={kbt}")

ax.set_title(f"Pureza - Modelo Lieb Matis - N={N} - J={J} - Δ={delta}", fontsize=14)
ax.grid()
ax.set_xlabel('Tiempo', fontsize=14)
ax.set_ylabel('Pureza', fontsize=14)
ax.legend(fontsize=14)

plt.show()
